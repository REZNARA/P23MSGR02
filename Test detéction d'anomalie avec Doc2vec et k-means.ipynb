# %% [markdown]
# ## Détection d'anomalie avec k-means, en utilisant doc2vec et PCA

# %% [markdown]
# Pour ce notebook, on s'est basé sur 3 projets trouvés sur Kaggle et Medium, Nous avons assemblé quelques classes et essayé de contruire un modèle à partir du mix. A la fin, nous n'avons pas pu terminer l'apprentissage du modèle (k-means), vu les PCs modestes que nous avons et le faite qu'on a épuisé le temps GPU sur colab que nous avons acheté.

# %%
import pandas as pd  
 
df = pd.read_csv("./tweets_with_sentiments.csv")    
df
# Out:
#                        id                                 preprocessed_tweet  \
# 0     1323650510029791233  RT WashingtonNFL RT digital sticker exercised ...
# 1     1323650510013059073  RT MisikoMichael WhiteHouse vote Trump vote ch...
# 2     1323650509836849153  RT justfivefoottwo vote Trump tomorrow make su...
# 3     1323650509765574657                              sammyliddell929 Trump
# 4     1323650509555802114  RT matthewjdowd Trump Biden went church choice...
# ...                   ...                                                ...
# 9995  1323650144492003330  RT MsJazzybelle Trump didnt MAKE ppl racist al...
# 9996  1323650144483508226  RT atrupar Putting marker likely event Trump l...
# 9997  1323650144450056194  RT JoeBiden Voting right question reach Voter ...
# 9998  1323650144424796160         RT pxola_01 voted Trump unfollow exception
# 9999  1323650144412160000  RT mikeroman ILLEGAL campaigning INSIDE pollin...
#
#       sentiment
# 0             5
# 1             1
# 2             1
# 3             5
# 4             1
# ...         ...
# 9995          1
# 9996          1
# 9997          1
# 9998          1
# 9999          1
#
# [10000 rows x 3 columns]

# %%
df.head()
# Out:
#                     id                                 preprocessed_tweet  \
# 0  1323650510029791233  RT WashingtonNFL RT digital sticker exercised ...
# 1  1323650510013059073  RT MisikoMichael WhiteHouse vote Trump vote ch...
# 2  1323650509836849153  RT justfivefoottwo vote Trump tomorrow make su...
# 3  1323650509765574657                              sammyliddell929 Trump
# 4  1323650509555802114  RT matthewjdowd Trump Biden went church choice...
#
#    sentiment
# 0          5
# 1          1
# 2          1
# 3          5
# 4          1

# %%
data_without_sentiment = df[['id', 'preprocessed_tweet']]  

data_without_sentiment = data_without_sentiment.head(10000)

# %%
data_without_sentiment
# Out:
#                      id                                 preprocessed_tweet
# 0   1323650510029791233  RT WashingtonNFL RT digital sticker exercised ...
# 1   1323650510013059073  RT MisikoMichael WhiteHouse vote Trump vote ch...
# 2   1323650509836849153  RT justfivefoottwo vote Trump tomorrow make su...
# 3   1323650509765574657                              sammyliddell929 Trump
# 4   1323650509555802114  RT matthewjdowd Trump Biden went church choice...
# ..                  ...                                                ...
# 95  1323650505671954433  RT ErinAlbinHill Im tired hearing people say w...
# 96  1323650505617362944  Yamiche thats news use Lets go Michigan like h...
# 97  1323650505575342080  RT CYBERCOM_DIRNSA US_CYBERCOM amp NSAGov Than...
# 98  1323650505550286848  RT AymanM Election Day President Trump intervi...
# 99  1323650505504161793  RT nytimes number Central American child impro...
#
# [100 rows x 2 columns]

# %%
def _read_all_election_tweets():    
    all_tweets = {}    
    for index, row in data_without_sentiment.iterrows():    
        tweet = row['preprocessed_tweet']    
        all_tweets[row['id']] = tweet    
    return all_tweets    
  
all_election_tweets = _read_all_election_tweets()

# %%
all_election_tweets
# Out:
# {1323650510029791233: 'RT WashingtonNFL RT digital sticker exercised right vote DMVotes x ElectionDay httpstco3sAWJjWwTu',
#  1323650510013059073: 'RT MisikoMichael WhiteHouse vote Trump vote chaos amp division dishonesty amp lie corruption amp criminality greed amp',
#  1323650509836849153: 'RT justfivefoottwo vote Trump tomorrow make sure explain gay trans female black Latinao Muslim friend',
#  1323650509765574657: 'sammyliddell929 Trump',
#  1323650509555802114: 'RT matthewjdowd Trump Biden went church choice today Biden went mass St Josephs Wilmington DE Tru',
#  1323650509396307968: 'RT MarciaJacobs13 Dont let trump fool tax Remember he tax cheat trying fool gullible people Dont gullible',
#  1323650509253840902: 'RT kaitlancollins campaign belief tonight landslide Kayleigh McEnany appearing White House press secreta',
#  1323650509241278467: 'RT aricnesbitt Porter Township Hall morning Van Buren County Michigan Ive never wait line longer 6 people whe',
#  1323650509144793088: 'RT COOLCHICBLONDE Election Day u care even little bit life others please vote blue dont know many peo',
#  1323650508976988165: 'RT gsjh59 NY State Local story Trump Train Rally held upstate town last weekend event promotor obtain insur',
#  1323650508859543554: 'Fwiw Trump loses dems arent gon na give boogeyman fact theyll work overtime convince th httpstcogHqfneEaQQ',
#  1323650508620361730: 'RT PiperPerabo Happy ElectionDay 1866OurVote help vote matter deserves counted ques',
#  1323650508561641472: 'RT BarbMcQuade Trump campaign amp GOP involved 40 voting case around country exactly none zero trying make',
#  1323650508477878274: 'People Color Vote Trump Yall Know White Folks Dont Give Rats Ass Yall Right',
#  1323650508444200960: 'RT VitalikButerin Ok look like earlier comment election prediction statistical model need adjusting New model highl',
#  1323650508436000768: 'trump putting fence around White House',
#  1323650508368842752: 'RT ErinAlbinHill Im tired hearing people say weve survived 4 year Trump survive 4 LOT people w',
#  1323650508314284034: 'RT mxmtoon voted joe biden voting blue election matter enormously many others force vote f',
#  1323650508247257089: 'RT JohnBrennan day change history day America say Donald Trumps lie hatefille',
#  1323650508146544640: 'ajm0701 Oh yeah fucked Especially Trump trying stop postal service',
#  1323650508104630275: 'RT LisaMarieBoothe Joe Biden spent election convincing Americans vote Donald Trump never convinced',
#  1323650508096073728: 'neal_katyal HOTEL TRUMP',
#  1323650508037394440: 'RT NikoNe_san_2525 人 VOTE President Trump four year MAGA Vote realDonaldTrump Election2020 ト',
#  1323650507970387968: 'BlogVermelho JoeBiden Butt hurt much biased thing trust Polls wrong Wakeup',
#  1323650507890692098: 'RT salty_ashley u voted trump mean disrespectful way possible want anything',
#  1323650507768913926: 'RT charliekirk11 Today day Time retire Joe Biden back basement end 47 year career corruption selfdealin',
#  1323650507764891648: 'UncleBu77496472 Dont worry Trumps reign almost BidenHarris2020',
#  1323650507718729729: 'RT ddale8 Trump last night introduced Lil Pump Lil Pimp called hypersonic missile hydrosonic missile talking length',
#  1323650507676639232: 'RT LVNancy Trump Fox Friends Weak leadership Blue States amp Democrat run city reason boarding radi',
#  1323650507630661633: 'RT MKGRDC Trump supporter going home listening Lil Pump music endorsed Trump httpstco5ZCq7F6aj6',
#  1323650507601227777: 'RT mHow250 mean really cult even presidency anymore didnt see stuff like Romney didnt see',
#  1323650507592839171: 'RT JoeBiden 2008 2012 placed trust help lead country alongside Barack Obama Today Im asking',
#  1323650507563438081: 'ivanka trump iowa hundred people showed event rumor person paid 75 attend event',
#  1323650507550859264: 'RT thegoodgodabove Predictions Trump loses Trump declares victory tonight Media report widely Trump declared victory H',
#  1323650507425140736: 'RT michaelianblack OFFICIAL PRESIDENTIAL ENDORSEMENT THREAD know difficult make mind',
#  1323650507378991105: 'Donald Trump Hulkamaniac Whacha gon na brother httpstcoSp42Ayy3Q9',
#  1323650507370602497: 'Zimbabwe given shock Pakistan Trump given India httpstco8Mds78INVh',
#  1323650507294998528: 'RT clairecmc special program show creative work gone great video opposing Trump min',
#  1323650507248984066: 'RT carlyjcor Trump supporter going vote person tomorrow he put distrust early voting number expec',
#  1323650507244785666: 'RT sarahmucha receiving 5 vote Dixville Notch Joe Biden joked Scranton Based Trumps notion Im going declare',
#  1323650507165061120: 'RT JoshMartinNC9 12 minute Thats took wait longer worth change want see',
#  1323650507165048833: 'RT Mikel_Jollett election day Donald Trump NEVER released 1 tax 2 health care plan',
#  1323650507139878921: 'KamalaHarris JoeBiden White House',
#  1323650507131490310: 'RT TeamDreamville seeing Lil Pump Trump rally httpstcoNsIXS6ULbD',
#  1323650507102134273: 'RT ZekeJMiller FLOTUS voted Palm Beach via pool report 10 Melania Trump entered Morton Barbara Mandel Recrea',
#  1323650507093671938: 'RT _AyaHijazi_ Trump leaned amp said know released dont succeeded amp Obama failed vulnerable',
#  1323650507064311809: 'Youll win httpstcoDMiTpbZVV7',
#  1323650507014049801: 'DarkMatter2525 Bisexuals kill saviour Donald J Trump',
#  1323650507009904643: 'know Ive kept quiet current event everyone able vote voting neve httpstco3gfGXR8yb4',
#  1323650506967965698: 'RT JoeBiden Everybody know Donald Trump Lets show choose hope fear Unity division Science ove',
#  1323650506946871296: 'RT Cleavon_MD Trump know doctor get money someone dy COVID Truth took 20 pay cut due le patient L',
#  1323650506913390592: 'RT PSLMemesWalay Misbah would ignore Trump Biden vote Iftikhar US Presedential election',
#  1323650506913361920: 'RT jasithedon fact trump supporter getting escorted protected police BLM activist getting killed th',
#  1323650506888282112: 'RT USAmbUK side side generation SpecialRelationship Read oped Daily_E',
#  1323650506867183621: 'RT wkamaubell Trumps advisor Mr President good closing argument Youve ruined economy reputation overseas',
#  1323650506779095040: 'RT jasithedon fact trump supporter getting escorted protected police BLM activist getting killed th',
#  1323650506749784064: 'Roblox Yall voting trump right',
#  1323650506728812548: 'RT salty_ashley u voted trump mean disrespectful way possible want anything',
#  1323650506716307457: 'Blueequus775 KelsBerg Exactly removed every friend family member support Trump life httpstcoRGQnDDGrUe',
#  1323650506645012484: 'RT mmpadellan Joe Biden already crack dawn today church visiting son grave Meanwhile trump sound exhaus',
#  1323650506640732163: 'RT sisterquiche mac miller publicly called trump waste skin bone something shifted httpstcoD2XQzHpXXx',
#  1323650506603012098: 'RT tajiareed Please dont let shit like make complacent Trump supporter large voting PERSON vote',
#  1323650506539982849: 'RT _kylandia voted trump cant friend simple',
#  1323650506523332608: 'hot take election come Trump loss PA step whatever httpstco2Q0BlPLiXo',
#  1323650506464632832: 'Trump campaign YouTube homepage Election Day first video rotation titled Obvious httpstcoVPptKO50Zf',
#  1323650506431102976: 'RT LifeNewsHQ President Trump Issues Proclamation Promoting Adoption Alternative Abortion httpstcorUYiDmQrVY httpstco',
#  1323650506401734658: 'desual daviddoel Poland trump doesnt abysmal approval rating',
#  1323650506397536258: 'RT ConservaMomUSA VoterSuppression Voting machine prorealDonaldTrump Borough Park Brooklyn allegedly broken amp lockedafte',
#  1323650506393292800: 'RT LucyTreadwell01 AnctNightmare HoodedMan TheWrongWoman KrookedKopKamala Snake WARren done everything aid ab',
#  1323650506384904194: 'Anotando mi oomfs trump supporter para futuras tareas httpstcog9n6JZdivP',
#  1323650506380685313: 'RT Nick_Olaz Trump understands God fear woman ElectionDay CCTV Elections2020 tiwa httpstcoL5jYb1csYz',
#  1323650506363908099: 'RT atrupar Trump bizarrely claim US harder deal Russia North Korea though America foreign country',
#  1323650506355400706: 'alfranken JoeBiden Oh well guess well make seeing Trump orange jumpsuitbummer',
#  1323650506292604928: 'RT nprpolitics final day 2020 election President Trump repeating false claim vote counted aft',
#  1323650506246553602: 'RT Scaramucci realDonaldTrump going get destroyed Video httpstcox6QXolUSTk',
#  1323650506229719040: 'trump surrounded traitor one antiUSA president history httpstcojed5ZAzEni',
#  1323650506192015360: 'RT kylegriffin1 Today Election Day Donald Trump never released health care plan',
#  1323650506187825162: 'RT LeighEllis LeBron James opened school gave struggling child access education Trump university pay 25',
#  1323650506137325569: 'RT BillKristol Today many u grateful 19th amendment since otherwise Donald Trump might getting reelected',
#  1323650506095529984: 'RT Clarissa_001 Texas 7am 7pm GO VOTE',
#  1323650506087190530: 'RT IvankaTrump Mood Election Day GAME DAY America Get VOTE TRUMP Vote VoteForTrump ElectionDa',
#  1323650506053586947: 'RT tribelaw Team Trump asking full Fifth Circuit suppress vote cast driver Harris County Theyre going lose',
#  1323650506045218819: 'RT RyanLizza Senior Senate GOP aide Trump despicable unAmerican surprising never respect',
#  1323650506041004033: 'RT PalmerReport Donald Trump call Fox amp Friends sound completely defeated half dead httpstco2WWrAfhAPw',
#  1323650506036793344: 'RT trschmidt85 Donald Melania vote twice reported voted mail Trump went voted early person',
#  1323650506032439296: 'RT LAist made ElectionDay question Need help Want know expect today Check Voter Game Plan http',
#  1323650506015805441: 'RT saladinahmed DNC establishment wont push federal holiday would empower truly working class electorate thatll u',
#  1323650505931812870: 'RT Yamiche Lil Pimp took stage Grand Rapids urge people vote President Trump',
#  1323650505890037760: 'RT JoeBiden 2008 2012 placed trust help lead country alongside Barack Obama Today Im asking',
#  1323650505864671233: 'RT Acosta Trump say Mexico pay wall something promised four year ago Never happened happening',
#  1323650505751580675: 'RT andimcam Trump winshis Proud Boys gon na feeling bold asf violent towards minority protestors',
#  1323650505726431232: 'RT PeteButtigieg Imagine feel first time sun come Donald Trump longer president United State',
#  1323650505722241024: 'RT salty_ashley u voted trump mean disrespectful way possible want anything',
#  1323650505684459522: 'RT MichelleObama know Joe lived life guided value principle mirror one Americans recognize',
#  1323650505684365312: 'RT thegoodgodabove Predictions Trump loses Trump declares victory tonight Media report widely Trump declared victory H',
#  1323650505671954433: 'RT ErinAlbinHill Im tired hearing people say weve survived 4 year Trump survive 4 LOT people w',
#  1323650505617362944: 'Yamiche thats news use Lets go Michigan like he living bubble Bullshit nobod httpstcoh5D0Xo6vfB',
#  1323650505575342080: 'RT CYBERCOM_DIRNSA US_CYBERCOM amp NSAGov Thank continued effort enduring priority safeguarding election',
#  1323650505550286848: 'RT AymanM Election Day President Trump interview Fox amp Friends talking China Plague httpstcobCN6hiW4CL',
#  1323650505504161793: 'RT nytimes number Central American child improperly expelled United States Mexico Trump administrati'}

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA


from gensim.models.doc2vec import TaggedDocument, Doc2Vec
from sklearn.base import BaseEstimator
from sklearn.metrics import silhouette_samples, silhouette_score  



from gensim.parsing.preprocessing import preprocess_string
from sklearn import utils
from tqdm import tqdm


from nltk.cluster import KMeansClusterer, cosine_distance

import multiprocessing
import numpy as np

from matplotlib import pyplot as plt

# %% [markdown]
# ## Génération d'un modèle d'espace vectoriel (Doc2Vec)

# %% [markdown]
# Cette étape consiste à convertir chaque array de tokenss correspondant à chaque tweet en vecteurs numériques. Cette étape est connue sous le nom de "génération d'un modèle d'espace vectoriel". Il existe des modèles d'espace vectoriel standard tels que "Tf-Idf", "Word2Vec", "Doc2Vec", etc. Ce vecteur fonctionne comme un vecteur de caractéristiques d'un document et détermine le nombre de caractéristiques qu'il contient. après avoir expérimenté en groupe le tf-idf et après quelques recherches sur internet, nous avons décidé  d'utilisé "Doc2Vec" comme modèle pour ce problème, au lieu d'utiliser TF-IDF comme annoncé dans notre vidéo, car chaque avis peut être considéré comme un document distinct. Et "Doc2Vec" fonctionne très bien pour comprendre le sens contextuel du texte (par rapport à Tf-Idf qui n'est rien d'autre qu'un modèle purement basé sur la fréquence).

# %%
class Doc2VecTransformer(BaseEstimator):  
  
    def __init__(self, vector_size=100, learning_rate=0.02, epochs=20):  
        self.learning_rate = learning_rate  # taux d'apprentissage  
        self.epochs = epochs  # nombre d'epochs  
        self._model = None  # modèle Doc2Vec  
        self.vector_size = vector_size  # taille du vecteur  
        self.workers = multiprocessing.cpu_count() - 1  # nombre de coeurs de processeur à utiliser  
  
    def fit(self, x, y=None):  
        tagged_x = [TaggedDocument(preprocess_string(item), [index]) for index, item in enumerate(x)]  # prétraitement des données et création des documents taggés  
        model = Doc2Vec(documents=tagged_x, vector_size=self.vector_size, workers=self.workers)  # création du modèle Doc2Vec  
  
        for epoch in range(self.epochs):  # boucle d'entraînement sur plusieurs epochs  
            model.train(utils.shuffle([x for x in tqdm(tagged_x)]), total_examples=len(tagged_x), epochs=1)  # entraînement du modèle sur les données taggées  
            model.alpha -= self.learning_rate  # diminution du taux d'apprentissage  
            model.min_alpha = model.alpha  
  
        self._model = model  # sauvegarde du modèle entraîné  
        return self  
  
    def transform(self, x):  
        arr = np.array([self._model.infer_vector(preprocess_string(item))  # transformation des données en vecteurs Doc2Vec  
                                     for index, item in enumerate(x)])  
        return arr  # renvoie des vecteurs transformés en numpy array

# %%
# Lecture de tous les tweets liés aux élections présidentielles  
election_tweets_dict = _read_all_election_tweets()  
election_tweets = election_tweets_dict.values()  
  
# Création du pipeline de transformation  
pl = Pipeline(steps=[('doc2vec', Doc2VecTransformer())])  
  
# Application du pipeline sur les données d'entrée pour transformer les textes en vecteurs Doc2Vec  
vectors_df = pl.fit(election_tweets).transform(election_tweets)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 99911.96it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# array([[-4.5587020e-03, -2.6597283e-03, -1.2905300e-05, ...,
#         -4.0697712e-03,  1.1009985e-03, -1.8362796e-03],
#        [-4.4795419e-03, -3.5272420e-03,  3.6088817e-03, ...,
#         -2.7936695e-03, -9.4900338e-04, -2.3520500e-03],
#        [ 4.5685767e-05,  4.1757612e-03,  4.7890007e-04, ...,
#          1.0168469e-03,  4.7854329e-03,  7.1840582e-04],
#        ...,
#        [ 4.1445061e-03, -4.7379234e-03, -3.5216340e-03, ...,
#          4.6391799e-03, -6.0618133e-04, -4.6638926e-03],
#        [ 4.4605789e-01, -3.5536239e-01, -3.5837725e-02, ...,
#         -7.3307708e-02,  3.3385652e-01,  3.9290476e-01],
#        [-3.6906451e-04, -3.3202702e-03,  2.7662141e-03, ...,
#          4.5417785e-03,  3.7260926e-03,  3.6071343e-03]], dtype=float32)

# %%
def analyze_election_tweets_pca(n_pca_components):  
    # Lecture de tous les tweets liés aux élections présidentielles  
    election_tweets_dict = _read_all_election_tweets()  
    election_tweets = election_tweets_dict.values()  
  
    # Transformation des tweets en vecteurs Doc2Vec  
    doc2vectors = Pipeline(steps=[('doc2vec', Doc2VecTransformer())]).fit(election_tweets).transform(election_tweets)  
  
    # Réduction de la dimension à l'aide de PCA  
    pca = PCA(n_components=n_pca_components)  
    pca_vectors = pca.fit_transform(doc2vectors)  
  
    # Affichage des résultats  
    print('Toutes les composantes principales ..')  
    print(pca_vectors)  
    for index, var in enumerate(pca.explained_variance_ratio_):  
        print("Rapport de variance expliquée par la composante principale ", (index+1), " : ", var)  
  
analyze_election_tweets_pca(n_pca_components=10)
# Out:
# All Principal Components ..
# [[-1.7023653e-01  1.5954165e-04 -3.0484665e-03 ...  4.8130648e-03
#   -2.0769904e-03 -3.5772007e-03]
#  [-1.7361657e-01  1.1969355e-03 -4.5162020e-03 ...  1.0025652e-04
#    1.6694883e-04 -3.0857258e-04]
#  [-1.7391200e-01 -4.6100579e-03 -1.6151712e-03 ...  8.1661501e-04
#    1.5345481e-03  8.4866816e-03]
#  ...
#  [-1.0101116e-01 -1.5672081e-03  1.1592152e-03 ... -2.8853046e-03
#   -2.8654758e-03 -3.2708819e-03]
#  [-1.0225602e-01 -5.1196333e-04 -3.8000715e-03 ... -7.5033470e-03
#    2.0123278e-03 -4.1980138e-03]
#  [-1.0621334e-01 -4.8767314e-03  7.5402530e-04 ... -2.8610772e-03
#   -3.0623898e-03 -2.6395633e-03]]
# Explained Variance ratio by Principal Component  1  :  0.9970804
# Explained Variance ratio by Principal Component  2  :  8.036091e-05
# Explained Variance ratio by Principal Component  3  :  7.469547e-05
# Explained Variance ratio by Principal Component  4  :  6.0406262e-05
# Explained Variance ratio by Principal Component  5  :  5.8748778e-05
# Explained Variance ratio by Principal Component  6  :  5.5895212e-05
# Explained Variance ratio by Principal Component  7  :  5.3270407e-05
# Explained Variance ratio by Principal Component  8  :  5.1535826e-05
# Explained Variance ratio by Principal Component  9  :  5.1061434e-05
# Explained Variance ratio by Principal Component  10  :  5.0435527e-05

# %%
class OptimalKMeansTextsClusterTransformer(BaseEstimator):  
  
    def __init__(self, min_k, max_k):  
        self.min_k = min_k  # nombre minimum de clusters  
        self.max_k = max_k  # nombre maximum de clusters  
  
    def fit(self, x, y=None):  
        return self  
  
    def _silhouette_score_with_k_(self, vectors, k):  
        # Clusterisation avec le nombre de clusters k  
        clusterer = KMeansClusterer(num_means=k, distance=cosine_distance, repeats=3)  
        cluster_labels = clusterer.cluster(vectors=vectors, assign_clusters=True, trace=False)  
  
        # Calcul du score de silhouette pour le nombre de clusters k  
        silhouette_score_k = silhouette_score(X=vectors, labels=cluster_labels, metric='cosine')  
        return k, silhouette_score_k  
  
    def _determine_k_for_max_silhouette_score_(self, process_responses):  
        # Recherche du nombre optimal de clusters pour lequel le score de silhouette est maximal  
        max_silhouette_score = -100.0  
        optimal_k = 2  
        for index, process_response in enumerate(process_responses):  
            current_k, silhouette_score_k = process_response.get()  
            print('Score de silhouette: ', silhouette_score_k, ' pour k=', current_k)  
            if silhouette_score_k > max_silhouette_score:  
                max_silhouette_score = silhouette_score_k  
                optimal_k = current_k  
  
        return optimal_k  
  
    def transform(self, x):  
        # Création de plusieurs clusteriseurs avec des nombres de clusters différents  
        range_of_k = [x for x in range(self.min_k, self.max_k)]  
        clusterer_pool = multiprocessing.Pool(processes=len(range_of_k))  
        clusterer_process_responses = []  
        for k in range_of_k:  
            clusterer_process_responses.append(clusterer_pool.apply_async(self._silhouette_score_with_k_, args=(x, k,)))  
  
        # Recherche du nombre optimal de clusters pour lequel le score de silhouette est maximal  
        optimal_k = self._determine_k_for_max_silhouette_score_(process_responses=clusterer_process_responses)  
  
        # Clusterisation avec le nombre de clusters optimal  
        print("Nombre optimal de clusters: ", optimal_k)  
        optimal_clusterer = KMeansClusterer(num_means=optimal_k, distance=cosine_distance, repeats=3)  
        optimal_cluster_labels = optimal_clusterer.cluster(vectors=x, assign_clusters=True, trace=False)  
  
        return x, optimal_cluster_labels

# %%
def determine_anomaly_tweets_k_means(top_n):  
    # Lecture de tous les tweets liés à la santé  
    tweets_dict = _read_all_election_tweets()  
    tweets = tweets_dict.values()  
  
    # Création d'un pipeline avec Doc2VecTransformer, PCA et OptimalKMeansTextsClusterTransformer  
    pl = Pipeline(steps=[('doc2vec', Doc2VecTransformer()),  
                         ('pca', PCA(n_components=2)),  
                         ('kmeans', OptimalKMeansTextsClusterTransformer(min_k=2, max_k=3))])  
    pl.fit(tweets)  
  
    # Récupération des vecteurs PCA et des étiquettes de cluster  
    pca_vectors, cluster_labels = pl.transform(tweets)  
  
    # Calcul des scores de silhouette pour chaque tweet  
    silhouette_values = silhouette_samples(X=pca_vectors, labels=cluster_labels, metric='cosine')  
  
    # Tri des tweets selon leur score de silhouette absolu  
    tweet_index_silhouette_scores = []  
    absolute_silhouette_scores_tweet_index = []  
    for index, sh_score in enumerate(silhouette_values):  
        absolute_silhouette_scores_tweet_index.append((abs(sh_score), index))  
        tweet_index_silhouette_scores.append((index, sh_score))  
    sorted_scores = sorted(absolute_silhouette_scores_tweet_index, key=sort_key)  
  
    # Affichage des top_n tweets avec les scores de silhouette les plus élevés  
    top_n_silhouette_scores = []  
    pca_vectors_anomalies = []  
    print("Top ", top_n, " anomalies")  
    for i in range(top_n):  
        abs_sh_score, index = sorted_scores[i]  
        index_1, sh_score = tweet_index_silhouette_scores[index]  
        top_n_silhouette_scores.append((index, sh_score))  
  
        # Affichage du tweet, du vecteur PCA et du score de silhouette  
        print(tweets_dict[index])  
        print('Vecteur PCA', pca_vectors[index])  
        pca_vectors_anomalies.append(pca_vectors[index])  
        print('Score de silhouette :', sh_score)  
        print("..................")  
  
    # Affichage des clusters K-means avec les tweets anormaux  
    plot_tweets_k_means_clusters_with_anomalies(pca_vectors=pca_vectors, pca_vectors_anomalies=pca_vectors_anomalies,  
                                                cluster_labels=cluster_labels)  
  
    # Affichage du graphique de dispersion des scores de silhouette  
    plot_scatter_silhouette_scores(top_n_silhouette_scores=top_n_silhouette_scores,  
                                   tweets_dict=tweets_dict,  
                                   silhouette_score_per_tweet=tweet_index_silhouette_scores)  
determine_anomaly_tweets_k_means(top_n=5)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 97360.82it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<?, ?it/s]
